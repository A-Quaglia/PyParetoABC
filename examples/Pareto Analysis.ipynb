# %%
import pandas as pd
from paretoabc import ParetoABC

products = pd.read_csv("../data/office_co.csv", sep=';')

pareto_anls = ParetoABC(products, abc_column="Revenue")

pareto_anls.abc()
pareto_anls.df
# Out:
#                        Prodct  Revenue  rank  items representation  \
# 0           Backup batteries      50.0   1.0                 0.025
# 1                    Webcams      50.0   2.0                 0.050
# 2                   Staplers      50.0   3.0                 0.075
# 3             Business cards      50.0   4.0                 0.100
# 4                  Shredders      50.0   5.0                 0.125
# 5                   Scissors      50.0   6.0                 0.150
# 6              Post it notes      50.0   7.0                 0.175
# 7                 Desk lamps      50.0   8.0                 0.200
# 8                Smartphones      30.0   9.0                 0.225
# 9                    Laptops      30.0  10.0                 0.250
# 10                     Paper      20.0  11.0                 0.275
# 11                   Printer      20.0  12.0                 0.300
# 12                      Glue      20.0  13.0                 0.325
# 13  Ink and toner cartridges      20.0  14.0                 0.350
# 14          Correction fluid      20.0  15.0                 0.375
# 15              Highlighters      20.0  16.0                 0.400
# 16                    Rulers      20.0  17.0                 0.425
# 17                   Tablets      15.0  18.0                 0.450
# 18               Paper clips      10.0  19.0                 0.475
# 19           Computer chairs      10.0  20.0                 0.500
# 20                 Notebooks       7.0  21.0                 0.525
# 21                      Pens       5.0  22.0                 0.550
# 22          Surge protectors       5.0  23.0                 0.575
# 23                  Keyboard       5.0  24.0                 0.600
# 24      Networking equipment       5.0  25.0                 0.625
# 25             Copy machines       3.0  26.0                 0.650
# 26                   Folders       3.0  27.0                 0.675
# 27                   Binders       2.0  28.0                 0.700
# 28           Desk organizers       1.0  29.0                 0.725
# 29                 Envelopes       1.0  30.0                 0.750
# 30                    Labels       1.0  31.0                 0.775
# 31             File cabinets       1.0  32.0                 0.800
# 32                     Mouse       1.0  33.0                 0.825
# 33                Headphones       1.0  34.0                 0.850
# 34                  Speakers       1.0  35.0                 0.875
# 35                USB drives       1.0  36.0                 0.900
# 36               Whiteboards       1.0  37.0                 0.925
# 37                     Tapes       1.0  38.0                 0.950
# 38      External hard drives       1.0  39.0                 0.975
# 39               Calculators       1.0  40.0                 1.000
#
#     values representation abc_labels
# 0                0.073314          A
# 1                0.146628          A
# 2                0.219941          A
# 3                0.293255          A
# 4                0.366569          A
# 5                0.439883          A
# 6                0.513196          A
# 7                0.586510          A
# 8                0.630499          B
# 9                0.674487          B
# 10               0.703812          B
# 11               0.733138          B
# 12               0.762463          B
# 13               0.791789          B
# 14               0.821114          B
# 15               0.850440          B
# 16               0.879765          B
# 17               0.901760          B
# 18               0.916422          B
# 19               0.931085          B
# 20               0.941349          B
# 21               0.948680          B
# 22               0.956012          B
# 23               0.963343          B
# 24               0.970674          B
# 25               0.975073          B
# 26               0.979472          B
# 27               0.982405          B
# 28               0.983871          C
# 29               0.985337          C
# 30               0.986804          C
# 31               0.988270          C
# 32               0.989736          C
# 33               0.991202          C
# 34               0.992669          C
# 35               0.994135          C
# 36               0.995601          C
# 37               0.997067          C
# 38               0.998534          C
# 39               1.000000          C

# %%
summary = pareto_anls.make_summary()
summary
# Out:
#   Labels  items representation  values representation
# 0      A                   0.2               0.586510
# 1      B                   0.7               0.982405
# 2      C                   1.0               1.000000
